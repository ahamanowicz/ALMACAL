# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import Planck15 as cosmo

# %%
def CO10_Lum_prime(z,Int_flux):
    co = 115.27

    dL = cosmo.luminosity_distance(z).value
    Lline_prime = 3.257e7 * Int_flux *  dL**2/(1+z)/co**2 #K km/s pc^2

    return Lline_prime

# %%
galaxy_catalogue=np.loadtxt('catalogue-for-almacal-new.txt')

# %%
xedges=np.load("xbins_new.npy")
yedges=np.load("ybins_new.npy")

# %%
x=np.array([[1,2],[3,4],[5,6]])
print(x)
x1=x[(x.T[0]>1) & (x.T[0]<6)]
print(x1)
x2=x1[(x1.T[1]>4)]
print(x2)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[3 4]
#  [5 6]]
# [[5 6]]

# %%
nbins=np.size(xedges)

K = np.size(galaxy_catalogue.T[0])
z = galaxy_catalogue.T[2]

J=11
Ico = np.log10(galaxy_catalogue.T[J])

HJco10 =np.zeros((nbins,nbins))
HJco10_sig = np.zeros((nbins,nbins))

# %%
for J in range(11,20,1):
    for i in range(nbins-1): #find position on the histogram
        z1=galaxy_catalogue[(z >= xedges[i]) & (z < xedges[i+1])]
        #print(np.size(z1))
        for j in range(nbins-1):
            I1=z1[(np.log10(z1.T[J]) >=yedges[j]) & (np.log10(z1.T[J]) < yedges[j+1])]
            
            HJco10[j][i] = np.median(I1.T[10])
            print(J,xedges[i],np.log10(CO10_Lum_prime(xedges[i],HJco10[j][i] /1.e3)))
            
            HJco10_sig[j][i] = np.std(HJco10)
            
    np.save("I_CO1_"+str(J-9)+".npy",HJco10)
# Out:
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 nan
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# 11 0.0 -inf
# ...

# %%
for J in range(2,10,1):
    plt.figure()
    H=np.load("I_CO1_"+str(J)+".npy")
    plt.imshow(H, origin='bottom')

# %%
Candidates 1 / 8
J0006-0623
1 -0.338 0.0
2 -0.008 0.0
3 0.323 0.0
3 0.323 12.328
4 0.654 29.65
5 0.984 43.29
6 1.315 14.526

# %%
def CO10_Lum_prime(z,Int_flux):
    co = 115.27

    dL = cosmo.luminosity_distance(z).value
    print(dL)
    Lline_prime = 3.257e7 * Int_flux *  dL**2/(1+z)/co**2 #K km/s pc^2
    return Lline_prime

# %%
flux1,z1=243, 0.185
flux2,z2=62, 0.131

# %%
print(np.log10(CO10_Lum_prime(z1,flux1/1e3)))
print(np.log10(CO10_Lum_prime(z2,flux2/1e3)))
# Out:
# 927.4106505356293
# 8.635817253691872
# 635.3564782703373
# 7.734349181752336

# %%
print(np.log10(4.3))
# Out:
# 0.6334684555795865

# %%
V1=1355.2
lumtot1=10**10.72 * 0.12 + 10**7.2 * 0.014 + 10**2 * 0.14 + 10**7.2 *0.016 + 10**11.09 * 0.13 + 10**10.96 * 0.13 + 10**11.27*0.16 + 10**10.64 + 10**10.74
print(lumtot1)
mh1=lumtot1 * 4.3 /V1

print(np.log10(mh1))
# Out:
# 162546864733.5278
# 8.71244365966681

# %%
V2=6558.1
lumtot2=10**11.47*0.3 + 10**12.11 * 0.43 + 10**11.9 * 0.39+ 10**11.8 + 0.36 + 10**11.69*0.34 + 10**12.33 * 0.46 + 10**11.8*0.3 + 10**11.77 * 0.23
mh2=lumtot2 * 4.3 /V2
print(np.log10(mh2))
# Out:
# 9.302119031957716

# %%
l
